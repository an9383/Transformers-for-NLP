# %% [markdown]
# #Semantic Role Labeling with ChatGPT
# Copyright 2023 Denis Rothman, MIT License
#
# This notebook shows how to use GPT-3.5(ChatGPT) with the OpenAI API to perform SRL tasks:
#
# 1. Installing openai and your API key<br>
# 2. Semantic Role Labeling as exaplained in *Tranformers for NLP, 2nd Edition, Chapter 10, Semantic Role Labeling.*
#
# To get the best out of this notebook:
# *   read Transformers for NLP, *Chapter 7, The Rise of Suprahuman Transformers with GPT-3 Engines* to understand the architecture of GPT engines. ChatGPT is GPT-3.5 turbo, a GPT model trained a large dataset. A GPT-3.5 turbo engine is a variant of a GPT Model.
#
# *  go through the notebooks in the [BONUS directory](https://github.com/Denis2054/Transformers-for-NLP-2nd-Edition/tree/main/Bonus#readme) to learn how to implement GPT-3.5 turbo(ChatGPT).
#
# *  once you have understood the theory of GPT transformers and explored the BONUS notebooks, try different sentences you find on social media that you would like to analyze in this notebook.

# %% [markdown]
# # December 6,2023 OpenAI API update
#
# [This notebook has been updated. See README "Getting Started with OpenAI API" section before running this notebook](https://github.com/Denis2054/Transformers-for-NLP-2nd-Edition/blob/main/README.md#getting-started-with-openai-api)

# %%
# !pip install --upgrade pip

# %%
# # December 4,2023 update : Tiktoken required to install OpenAI on Google Colab
# # Tiktoken is a fast BPE tokenizer
# !pip install tiktoken

# # December 4,2023 update : Cohere required to install OpenAI to implement language AI.
# # Cohere platform: https://dashboard.cohere.com/
# !pip install --upgrade cohere

# %% [markdown]
# #1.Installing openai

# %% [markdown]
# ## installing and importing openai

# %%
#Importing openai
try:
  import openai
except:
  # !pip install openai
  import openai

# %% [markdown]
# ##API Key

# %%
#2.API Key
#Store you key in a file and read it(you can type it directly in the notebook but it will be visible for somebody next to you)
# from google.colab import drive
# drive.mount('/content/drive')
# f = open("drive/MyDrive/files/api_key.txt", "r")
# API_KEY=f.readline()
# f.close()

#The OpenAI Key
import os
os.environ['OPENAI_API_KEY']
openai.api_key = os.getenv("OPENAI_API_KEY")

# %%
# December 6,2023
from openai import OpenAI
client = OpenAI(
    # This is the default and can be omitted
    api_key=os.environ.get("OPENAI_API_KEY"),
)

# %% [markdown]
# #2.ChatGPT dialog function

# %% [markdown]
# preparing the NLP message

# %%
 def dialog(uinput):
   #preparing the prompt for OpenAI
   role="user"

   #prompt="Where is Tahiti located?" #maintenance or if you do not want to use a microphone
   line = {"role": role, "content": uinput}

   #creating the mesage
   assert1={"role": "system", "content": "You are a Natural Language Processing Assistant."}
   assert2={"role": "assistant", "content": "You are helping viewers analyze social medial better."}
   assert3=line
   iprompt = []
   iprompt.append(assert1)
   iprompt.append(assert2)
   iprompt.append(assert3)

   #sending the message to ChatGPT
   response = client.chat.completions.create(model="gpt-4",messages=iprompt) #ChatGPT dialog
   text=response.choices[0].message.content

   return text

# %% [markdown]
# # 5.Semantic Role Labeling(SRL)

# %% [markdown]
# The 3 **basic** text samples are relatively easy. <br>
# The 4 **difficult** text samples are challenging.
#
# **Basic**
#
# Sample1:
# "Did Bob really think he could prepare a meal for 50 people in only a few hours?"
#
# Sample 2:
# "Mrs. and Mr. Tomaso went to Europe for vacation and visited Paris and first went to visit the Eiffel Tower."
#
# Sample 3:
# "John wanted to drink tea, Mary likes to drink coffee but Karim drank some cool water and Faiza would like to drink tomato juice."
#
# **Difficult**
#
# Sample 4 :ambiguous subject<br>
# "Alice, whose husband went jogging every Sunday, liked to go to a dancing class in the meantime."
#
# Sample 5: *round* can be a verb, a noun, preposition, etc.In this sentence, it is a verb<br>
# "The bright sun, the blue sky, the warm sand, the palm trees, everything round off."
#
# Sample 6: *ice* can be a noun or verb in Hockey<br>
# "Now, ice pucks guys!"
#
# Sample 7:confusing sentence with mixed descriptions<br>
# "Though the customer seemed unhappy, she was, in fact satisfied but thinking of something else at the time, which gave a false impression?""

# %% [markdown]
# ##Semantic Role Labeling(SRL) label list provided by ChatGPT

# %%
uinput="Provide the list of labels for Semantic Role Labeling"
text=dialog(uinput) #preparing the messages for ChatGPT
print("Viewer request",uinput)
print("ChatGPT Sentiment Analysis:",text)
# Out:
# Viewer request Provide the list of labels for Semantic Role Labeling
# ChatGPT Sentiment Analysis: Semantic Role Labeling (SRL) is a task in natural language processing that involves assigning labels to words or phrases in a sentence that indicate their semantic role in the sentence. Below are some common labels used in SRL:
#
# 1. Agent: The doer of an action.
# 2. Patient: The entity that the action is done to.
# 3. Instrument: The method, tool, or means by which the action is accomplished.
# 4. Location: Where the action takes place.
# 5. Beneficiary: The party for whom the action is done.
# 6. Cause: The reason why the action happened.
# 7. Time: When the action happens.
# 8. Manner: The way in which the action is done.
# 9. Purpose: The goal or intention behind the action.
# 10. Source: Where or whom the action originates from.
# 11. Target: Where or whom the action is directed at.
# 12. Theme: The object or concept that the sentence is about.
# 13. Experiencer: The entity that perceives or feels the action.
#
# It's important to note that the exact labels can vary based on the specific framework or tool used for SRL.

# %% [markdown]
# ## Basic samples

# %% [markdown]
# Sample1:<br>"Did Bob really think he could prepare a meal for 50 people in only a few hours?"

# %%
uinput="Perform Semantic Role Labeling on the following sentence:Did Bob really think he could prepare a meal for 50 people in only a few hours?"
text=dialog(uinput) #preparing the messages for ChatGPT
print("Viewer request",uinput)
print("ChatGPT Sentiment Analysis:",text)
# Out:
# Viewer request Perform Semantic Role Labeling on the following sentence:Did Bob really think he could prepare a meal for 50 people in only a few hours?
# ChatGPT Sentiment Analysis: Semantic Role Labeling (SRL) deals with understanding the roles that each entity in a sentence plays within the actions or states described. Let's break down your sentence:
#
# Sentence: "Did Bob really think he could prepare a meal for 50 people in only a few hours?"
#
# 1. Arg0 (Actor) : Bob
# 2. Verb (Action) : think, prepare
# 3. Arg1 (Experiencer of the action): he
# 4. Arg2 (Beneficiary/Target) :a meal
# 5. Arg3 (the action's recipient): 50 people
# 6. Arg4 (Temporal phrase): in only a few hours
#
# SRL aims to extract a simplified form of the sentence which might be: "[Bob]_Arg0 thinks [he]_Arg1 could prepare [a meal]_Arg2 for [50 people]_Arg3 in [only a few hours]_Arg4."
#
# This structure provides a clearer picture of the core meaning of the sentence and the roles each entity is playing.

# %% [markdown]
# Sample 2:<br>"Mrs. and Mr. Tomaso went to Europe for vacation and visited Paris and first went to visit the Eiffel Tower."

# %%
uinput="Perform Semantic Role Labeling on the following sentence:Mrs. and Mr. Tomaso went to Europe for vacation and visited Paris and first went to visit the Eiffel Tower."
text=dialog(uinput) #preparing the messages for ChatGPT
print("Viewer request",uinput)
print("ChatGPT Sentiment Analysis:",text)
# Out:
# Viewer request Perform Semantic Role Labeling on the following sentence:Mrs. and Mr. Tomaso went to Europe for vacation and visited Paris and first went to visit the Eiffel Tower.
# ChatGPT Sentiment Analysis: In the sentence, "Mrs. and Mr. Tomaso went to Europe for vacation and visited Paris and first went to visit the Eiffel Tower", the roles can be labeled as follows:
#
# Mrs. and Mr. Tomaso - ARG0 or Agent: These are the individuals performing the actions in the sentence.
#
# went to Europe - Predicate or Verb: This means the activity that the agent is carrying out. 'went' is the verb, and 'to Europe' is the location.
#
# for vacation - Purpose or ARG1: This describes the reason why the agent carried out the action.
#
# visited - Another Predicate or Verb: It indicates another activity the agent performed.
#
# Paris - Destination: This is the place that was visited by the agent, connected to the previous verb 'visited'.
#
# first went to - A Sequential Verb: This indicates the order of actions performed by the agent.
#
# visit the Eiffel Tower - Event/Activity and Target/Location: 'visit' is the action and 'the Eiffel Tower' is the target of the visit or the specific location where the action happened.

# %% [markdown]
# Sample 3: <br>
# "John wanted to drink tea, Mary likes to drink coffee but Karim drank some cool water and Faiza would like to drink tomato juice."

# %%
uinput="Perform Semantic Role Labeling on the following sentence:John wanted to drink tea, Mary likes to drink coffee but Karim drank some cool water and Faiza would like to drink tomato juice."
text=dialog(uinput) #preparing the messages for ChatGPT
print("Viewer request",uinput)
print("ChatGPT Sentiment Analysis:",text)
# Out:
# Viewer request Perform Semantic Role Labeling on the following sentence:John wanted to drink tea, Mary likes to drink coffee but Karim drank some cool water and Faiza would like to drink tomato juice.
# ChatGPT Sentiment Analysis: Semantic role labeling involves the identification of the sentence's various constituents (like agents, actions, and objects) and specification of the relationships among these constituents.
#
# Here's the semantic role labeling for the sentence:
#
# Sentence: "John wanted to drink tea, Mary likes to drink coffee but Karim drank some cool water and Faiza would like to drink tomato juice."
#
# Main Roles:
#
# 1. John (Agent) - wanted (Predicate) - to drink (Action) - tea (Object)
# 2. Mary (Agent) - likes (Predicate) - to drink (Action) - coffee (Object)
# 3. Karim (Agent) - drank (Action) - some cool water (Object)
# 4. Faiza (Agent) - would like (Predicate) - to drink (Action) - tomato juice (Object)
#
# Additional Roles:
#
# 1. "but" (Contrastive conjunction) indicates a contrast between the actions of Mary and Karim.
# 2. "and" (Coordinating conjunction) links the actions of Karim and Faiza.
#
# Please note that the agent carries out an action, the action is the process or state described by the verb, and the object is impacted by the agent's action. The predicate indicates the agent's attitude or relation to the action.

# %% [markdown]
# ## Difficult samples

# %% [markdown]
# Sample 4 :ambiguous subject<br>
# "Alice, whose husband went jogging every Sunday, liked to go to a dancing class in the meantime."

# %%
uinput="Perform Semantic Role Labeling on the following sentence:Alice, whose husband went jogging every Sunday, liked to go to a dancing class in the meantime."
text=dialog(uinput) #preparing the messages for ChatGPT
print("Viewer request",uinput)
print("ChatGPT Sentiment Analysis:",text)
# Out:
# Viewer request Perform Semantic Role Labeling on the following sentence:Alice, whose husband went jogging every Sunday, liked to go to a dancing class in the meantime.
# ChatGPT Sentiment Analysis: Semantic Role Labeling (SRL) is about identifying the roles that different parts of a sentence play in the overall meaning of the sentence. Here is the SRL for your sentence:
#
# Sentence: Alice, whose husband went jogging every Sunday, liked to go to a dancing class in the meantime.
#
# 1. Alice:
#    Role: Agent
#    Definition: The participant which the predicate happens to or is done to.
#
# 2. Whose husband went jogging every Sunday:
#    Role: Modifier
#    Definition: It is giving additional information about Alice.
#
# 3. Liked:
#    Role: Verb (Predicate)
#    Definition: The main verb in the sentence describing the action or state.
#
# 4. To go to a dancing class:
#    Role: Direct Object
#    Definition: The object that the main verb is acting upon.
#
# 5. In the meantime:
#    Role: Temporal
#    Definition: Specifies when the action of the verb took place.

# %% [markdown]
# Sample 5: *round* can be a verb, a noun, preposition, etc.In this sentence, it is a verb<br>
# "The bright sun, the blue sky, the warm sand, the palm trees, everything round off."

# %%
uinput="Perform Semantic Role Labeling on the following sentence:The bright sun, the blue sky, the warm sand, the palm trees, everything round off."
text=dialog(uinput) #preparing the messages for ChatGPT
print("Viewer request",uinput)
print("ChatGPT Sentiment Analysis:",text)
# Out:
# Viewer request Perform Semantic Role Labeling on the following sentence:The bright sun, the blue sky, the warm sand, the palm trees, everything round off.
# ChatGPT Sentiment Analysis: Semantic Role Labeling (SRL) is a task that assigns labels to words or phrases in a sentence that indicates their semantic role in the sentence, such as who did what to whom, when, where, how, etc. Here is an example of SRL for the sentence:
#
# "The bright sun, the blue sky, the warm sand, the palm trees, everything round off."
#
# 1. "The bright sun, the blue sky, the warm sand, the palm trees, everything" - ARG1 (Collection of Things, The entities that are rounding off or completing)
#
# 2. "round off." - PREDICATE (Action)
#
# In this sentence, it is tricky to identify roles because it is sort of a figurative expression, meaning that everything comes together perfectly. However, we can say that 'everything' refer to the listed entities that collectively complete or 'round off' the scene or situation. And 'round off' is the action taken by these entities.
#
# Please note that sentence structure and their semantic interpretations can vary and sometimes may not fit neatly into SRL frameworks.

# %% [markdown]
# Sample 6: *ice* can be a noun or verb in Hockey<br>
# This sentence seems to difficult for ChatGPT. The model isn't good at neing hockey coach!<br>
# "Now, ice pucks guys!"

# %%
uinput="Perform Semantic Role Labeling on the following sentence:Now, ice pucks guys!"
text=dialog(uinput) #preparing the messages for ChatGPT
print("Viewer request",uinput)
print("ChatGPT Sentiment Analysis:",text)
# Out:
# Viewer request Perform Semantic Role Labeling on the following sentence:Now, ice pucks guys!
# ChatGPT Sentiment Analysis: Semantic Role Labeling (SRL) is about understanding a sentence and assigning labels or roles to each word in the sentence. However, the sentence "Now, ice pucks guys!" is not grammatically complete, and it's tricky to understand exactly what each word's role is without more context. Here's an attempt:
#
# - "Now" would probably be a Temporal adjunct (AM-TMP), indicating when something is happening.
# - "Ice" of course is a noun (NN), but without more context, it's not clear what role it's playing. It might be acting as an Agent (A0) if the sentence is a command meaning "Ice the pucks, guys!"
# - "Pucks" could be a Patient (P1), the entity being acted upon ("the pucks are being iced") or a Theme (A1, the entity undergoing the action).
# - "Guys" could be an Agent (A0, the entity performing the action), but this only makes sense if the sentence is being interpreted as a command.
#
# Without more context, it's hard to be sure about these roles. They could change drastically depending on the intended meaning of the sentence.

# %% [markdown]
# Sample 7:confusing sentence with mixed descriptions<br>
# "Though the customer seemed unhappy, she was, in fact satisfied but thinking of something else at the time, which gave a false impression?"

# %%
uinput="Perform Semantic Role Labeling on the following sentence:Though the customer seemed unhappy, she was, in fact satisfied but thinking of something else at the time, which gave a false impression?"
text=dialog(uinput) #preparing the messages for ChatGPT
print("Viewer request",uinput)
print("ChatGPT Sentiment Analysis:",text)
# Out:
# Viewer request Perform Semantic Role Labeling on the following sentence:Though the customer seemed unhappy, she was, in fact satisfied but thinking of something else at the time, which gave a false impression?
# ChatGPT Sentiment Analysis: Semantic Role Labeling for the sentence:
#
# "Though the customer seemed unhappy, she was, in fact satisfied but thinking of something else at the time, which gave a false impression"
#
# 1. Arg0: The customer
# Function: Agent
# 2. Verb: seemed
# Function: Predicator
# 3. Arg1: unhappy
# Function: Attribute to Arg0
#
# 1. Arg0: She (referring to the customer)
# Function: Agent
# 2. Verb: was
# Function: State verb
# 3. Arg1: in fact satisfied
# Function: State attribute of Arg0
#
# Sub-Sentence: "but thinking of something else at the time"
#
# 1. ArgM-DIS: but
# Function: Conjunction / Discourse marker
# 2. Arg0: She (referring to the customer)
# Function: Agent
# 3. Verb: thinking
# Function: Predicator
# 4. Arg1: of something else
# Function: describes the content of thinking
# 5. ArgM-TMP: at the time
# Function: Temporal modifier of the situation
#
# Sub-Sentence: "which gave a false impression"
#
# 1. Arg1: which (Refers to the whole situation of the customer appearing unhappy but in fact being satisfied and preoccupied)
# Function: Pronoun, subject of the clause
# 2. Verb: gave
# Function: Predicator
# 3. Arg2: a false impression
# Function: Describes the voice of Arg1.
