# %% [markdown]
# #Semantic Role Labeling with ChatGPT
# Copyright 2023 Denis Rothman, MIT License
#
# This notebook shows how to use GPT-3.5(ChatGPT) with the OpenAI API to perform SRL tasks:
#
# 1. Installing openai and your API key<br>
# 2. Semantic Role Labeling as exaplained in *Tranformers for NLP, 2nd Edition, Chapter 10, Semantic Role Labeling.*
#
# To get the best out of this notebook:
# *   read Transformers for NLP, *Chapter 7, The Rise of Suprahuman Transformers with GPT-3 Engines* to understand the architecture of GPT engines. ChatGPT is GPT-3.5 turbo, a GPT model trained a large dataset. A GPT-3.5 turbo engine is a variant of a GPT Model.
#
# *  go through the notebooks in the [BONUS directory](https://github.com/Denis2054/Transformers-for-NLP-2nd-Edition/tree/main/Bonus#readme) to learn how to implement GPT-3.5 turbo(ChatGPT).
#
# *  once you have understood the theory of GPT transformers and explored the BONUS notebooks, try different sentences you find on social media that you would like to analyze in this notebook.

# %% [markdown]
# # December 6,2023 OpenAI API update
#
# [This notebook has been updated. See README "Getting Started with OpenAI API" section before running this notebook](https://github.com/Denis2054/Transformers-for-NLP-2nd-Edition/blob/main/README.md#getting-started-with-openai-api)

# %%
# !pip install --upgrade pip

# %%
# # December 4,2023 update : Tiktoken required to install OpenAI on Google Colab
# # Tiktoken is a fast BPE tokenizer
# !pip install tiktoken

# # December 4,2023 update : Cohere required to install OpenAI to implement language AI.
# # Cohere platform: https://dashboard.cohere.com/
# !pip install --upgrade cohere

# %% [markdown]
# #1.Installing openai

# %% [markdown]
# ## installing and importing openai

# %%
#Importing openai
try:
  import openai
except:
  # !pip install openai
  import openai

# %% [markdown]
# ##API Key

# %%
#2.API Key
#Store you key in a file and read it(you can type it directly in the notebook but it will be visible for somebody next to you)
# from google.colab import drive
# drive.mount('/content/drive')
# f = open("drive/MyDrive/files/api_key.txt", "r")
# API_KEY=f.readline()
# f.close()

#The OpenAI Key
import os
os.environ['OPENAI_API_KEY']
openai.api_key = os.getenv("OPENAI_API_KEY")

# %%
# December 6,2023
from openai import OpenAI
client = OpenAI(
    # This is the default and can be omitted
    api_key=os.environ.get("OPENAI_API_KEY"),
)

# %% [markdown]
# #2.ChatGPT dialog function

# %% [markdown]
# preparing the NLP message

# %%
 def dialog(uinput):
   #preparing the prompt for OpenAI
   role="user"

   #prompt="Where is Tahiti located?" #maintenance or if you do not want to use a microphone
   line = {"role": role, "content": uinput}

   #creating the mesage
   assert1={"role": "system", "content": "You are a Natural Language Processing Assistant."}
   assert2={"role": "assistant", "content": "You are helping viewers analyze social medial better."}
   assert3=line
   iprompt = []
   iprompt.append(assert1)
   iprompt.append(assert2)
   iprompt.append(assert3)

   #sending the message to ChatGPT
   response = client.chat.completions.create(model="gpt-4",messages=iprompt) #ChatGPT dialog
   text=response.choices[0].message.content

   return text

# %% [markdown]
# # 5.Semantic Role Labeling(SRL)

# %% [markdown]
# The 3 **basic** text samples are relatively easy. <br>
# The 4 **difficult** text samples are challenging.
#
# **Basic**
#
# Sample1:
# "Did Bob really think he could prepare a meal for 50 people in only a few hours?"
#
# Sample 2:
# "Mrs. and Mr. Tomaso went to Europe for vacation and visited Paris and first went to visit the Eiffel Tower."
#
# Sample 3:
# "John wanted to drink tea, Mary likes to drink coffee but Karim drank some cool water and Faiza would like to drink tomato juice."
#
# **Difficult**
#
# Sample 4 :ambiguous subject<br>
# "Alice, whose husband went jogging every Sunday, liked to go to a dancing class in the meantime."
#
# Sample 5: *round* can be a verb, a noun, preposition, etc.In this sentence, it is a verb<br>
# "The bright sun, the blue sky, the warm sand, the palm trees, everything round off."
#
# Sample 6: *ice* can be a noun or verb in Hockey<br>
# "Now, ice pucks guys!"
#
# Sample 7:confusing sentence with mixed descriptions<br>
# "Though the customer seemed unhappy, she was, in fact satisfied but thinking of something else at the time, which gave a false impression?""

# %% [markdown]
# ##Semantic Role Labeling(SRL) label list provided by ChatGPT

# %%
uinput="Provide the list of labels for Semantic Role Labeling"
text=dialog(uinput) #preparing the messages for ChatGPT
print("Viewer request",uinput)
print("ChatGPT Sentiment Analysis:",text)
# Out:
# Viewer request Provide the list of labels for Semantic Role Labeling
# ChatGPT Sentiment Analysis: Semantic Role Labeling (SRL) is a process in Natural Language Processing that assigns labels to words or phrases in a sentence that indicate their semantic role in the sentence, such as who is the agent, what action is being performed, what is receiving the action, etc. Here are some common labels used in Semantic Role Labeling:
#
# 1. Agent: The entity that performs the action.
# 2. Patient: The entity that the action is performed on.
# 3. Theme: What's being talked about in relation to the agent and patient.
# 4. Experiencer: The entity that experiences a certain situation/stimulus.
# 5. Cause: The cause that makes the action happen.
# 6. Beneficiary: The entity that benefits from the action.
# 7. Instrument: The entity that is used to do the action.
# 8. Location: The place where the action is performed or the scene of the event.
# 9. Source: The origin of the action or event.
# 10. Goal: The destination or intended result of the action.
#
# Note: The exact labels and its definitions might vary based on different semantic theories. They also can get more specific like manner, purpose, etc. based on the complexity of the text or sentence to be labeled. Moreover, important labels are also presented as A0, A1, A2, etc. in PropBank style of labeling where each Ai corresponds to an argument in the sentence. The specific interpretation of these arguments depends on the verb of the sentence.

# %% [markdown]
# ## Basic samples

# %% [markdown]
# Sample1:<br>"Did Bob really think he could prepare a meal for 50 people in only a few hours?"

# %%
uinput="Perform Semantic Role Labeling on the following sentence:Did Bob really think he could prepare a meal for 50 people in only a few hours?"
text=dialog(uinput) #preparing the messages for ChatGPT
print("Viewer request",uinput)
print("ChatGPT Sentiment Analysis:",text)
# Out:
# Viewer request Perform Semantic Role Labeling on the following sentence:Did Bob really think he could prepare a meal for 50 people in only a few hours?
# ChatGPT Sentiment Analysis: Semantic Role Labeling (SRL) dissects a sentence by showing the relationships that make up the sentence's meaning. Here is the Semantic Role Labeling for your sentence:
#
# - Bob (Agent)
# - really think (Predicate)
# - he (Agent)
# - could prepare (Predicate)
# - a meal (Patient)
# - for 50 people (Beneficiary)
# - in only a few hours (Temporal)
#
# In the sentence:
#
# - "Bob" is the person (the agent) thinking.
# - “really think” is the action (the predicate) performed by Bob.
# - "he" refers to Bob.
# - "could prepare" is the action (the predicate) that "he" is thinking about.
# - "a meal" is the entity (the patient) that is being prepared.
# - "for 50 people" is for whom the action is performed (the beneficiary).
# - "in only a few hours" is the time (the temporal) in which the action is to be completed.

# %% [markdown]
# Sample 2:<br>"Mrs. and Mr. Tomaso went to Europe for vacation and visited Paris and first went to visit the Eiffel Tower."

# %%
uinput="Perform Semantic Role Labeling on the following sentence:Mrs. and Mr. Tomaso went to Europe for vacation and visited Paris and first went to visit the Eiffel Tower."
text=dialog(uinput) #preparing the messages for ChatGPT
print("Viewer request",uinput)
print("ChatGPT Sentiment Analysis:",text)
# Out:
# Viewer request Perform Semantic Role Labeling on the following sentence:Mrs. and Mr. Tomaso went to Europe for vacation and visited Paris and first went to visit the Eiffel Tower.
# ChatGPT Sentiment Analysis: In Natural Language Processing, Semantic Role Labeling (SRL) is the process of assigning labels to words or phrases in a sentence that indicate their semantic role in the sentence.
#
# Here is the Semantic Role Labeling for your sentence: "Mrs. and Mr. Tomaso went to Europe for vacation and visited Paris and first went to visit the Eiffel Tower."
#
# Arg0: Mrs. and Mr. Tomaso (the entities performing the action)
# Verb: went
# Arg1: to Europe (destination of the action)
# ArgM-PNC: for vacation (purpose of the action)
#
# Verb: visited
# Arg1: Paris (destination of the action)
#
# Verb: went (repetition of the action, part of a sub-event)
# Arg1: to visit the Eiffel Tower (purpose of this action within the event)
#
# It's important to note that SRL seeks to identify the underlying relationship between entities and their actions, rather than just their syntactic relationship based on grammar.

# %% [markdown]
# Sample 3: <br>
# "John wanted to drink tea, Mary likes to drink coffee but Karim drank some cool water and Faiza would like to drink tomato juice."

# %%
uinput="Perform Semantic Role Labeling on the following sentence:John wanted to drink tea, Mary likes to drink coffee but Karim drank some cool water and Faiza would like to drink tomato juice."
text=dialog(uinput) #preparing the messages for ChatGPT
print("Viewer request",uinput)
print("ChatGPT Sentiment Analysis:",text)
# Out:
# Viewer request Perform Semantic Role Labeling on the following sentence:John wanted to drink tea, Mary likes to drink coffee but Karim drank some cool water and Faiza would like to drink tomato juice.
# ChatGPT Sentiment Analysis: John wanted to drink tea:
# - Agent: John
# - Action: wanted
# - Object: to drink tea
#
# Mary likes to drink coffee:
# - Agent: Mary
# - Action: likes
# - Object: to drink coffee
#
# Karim drank some cool water:
# - Agent: Karim
# - Action: drank
# - Object: some cool water
#
# Faiza would like to drink tomato juice:
# - Agent: Faiza
# - Action: would like
# - Object: to drink tomato juice

# %% [markdown]
# ## Difficult samples

# %% [markdown]
# Sample 4 :ambiguous subject<br>
# "Alice, whose husband went jogging every Sunday, liked to go to a dancing class in the meantime."

# %%
uinput="Perform Semantic Role Labeling on the following sentence:Alice, whose husband went jogging every Sunday, liked to go to a dancing class in the meantime."
text=dialog(uinput) #preparing the messages for ChatGPT
print("Viewer request",uinput)
print("ChatGPT Sentiment Analysis:",text)
# Out:
# Viewer request Perform Semantic Role Labeling on the following sentence:Alice, whose husband went jogging every Sunday, liked to go to a dancing class in the meantime.
# ChatGPT Sentiment Analysis: Semantic Role Labeling identifies the semantic roles in a sentence. The sentence here ("Alice, whose husband went jogging every Sunday, liked to go to a dancing class in the meantime.") can be broken down as follows:
#
# 1. Arg0 (Agent: the one who performs or causes the action): Alice
# 2. Arg1 (Patient: the entity that something is done to): dancing class
# 3. Verb: liked to go
# 4. ArgM-TMP (Temporal: the time when the action takes place): In the meantime
# 5. ArgM-ADV (Adverbial: the underlying reason or manner for an action): whose husband went jogging every Sunday
# 6. ArgM-LOC (Locational: where the action takes place): Not explicitly mentioned but implied at the dancing class.
#
# So the Semantic Role Labeling of the sentence can be displayed as: [Alice]_Arg0 [liked to go]_Verb [to a dancing class]_Arg1 [in the meantime.]_ArgM-TMP, [whose husband went jogging every Sunday]_ArgM-ADV.

# %% [markdown]
# Sample 5: *round* can be a verb, a noun, preposition, etc.In this sentence, it is a verb<br>
# "The bright sun, the blue sky, the warm sand, the palm trees, everything round off."

# %%
uinput="Perform Semantic Role Labeling on the following sentence:The bright sun, the blue sky, the warm sand, the palm trees, everything round off."
text=dialog(uinput) #preparing the messages for ChatGPT
print("Viewer request",uinput)
print("ChatGPT Sentiment Analysis:",text)
# Out:
# Viewer request Perform Semantic Role Labeling on the following sentence:The bright sun, the blue sky, the warm sand, the palm trees, everything round off.
# ChatGPT Sentiment Analysis: In Semantic Role Labeling, we usually identify the predicate (usually a verb) and its corresponding arguments such as agents, patients, instruments, locations, etc. However, your sentence: "The bright sun, the blue sky, the warm sand, the palm trees, everything round off." is a bit complex in terms of conventional semantic roles.
#
# If we break it down, here's a possible interpretation:
#
# 1. Predicate: "round off"
# 2. Arg1 (Theme which is undergoing the action): "The bright sun, the blue sky, the warm sand, the palm trees, everything"
#
# Please note that 'round off' is usually used in mathematical or numerical context. From a semantic point of view, it means to make something complete or perfect, but it's not often used to describe scenes or objects like sun, sky, sand, and trees. If 'round off' is used in the sense of 'completing the scene', then it might be a stylistic or figurative language choice outside the bounds of typical semantic role labeling.

# %% [markdown]
# Sample 6: *ice* can be a noun or verb in Hockey<br>
# This sentence seems to difficult for ChatGPT. The model isn't good at neing hockey coach!<br>
# "Now, ice pucks guys!"

# %%
uinput="Perform Semantic Role Labeling on the following sentence:Now, ice pucks guys!"
text=dialog(uinput) #preparing the messages for ChatGPT
print("Viewer request",uinput)
print("ChatGPT Sentiment Analysis:",text)
# Out:
# Viewer request Perform Semantic Role Labeling on the following sentence:Now, ice pucks guys!
# ChatGPT Sentiment Analysis: Semantic Role Labeling (SRL) involves understanding the relationships between different parts of a sentence to fulfill semantic roles. However, your sentence "Now, ice pucks guys!" seems ambiguous or incomplete and lacks context, which makes SRL difficult.
#
# In a typical SRL, we would look for the following elements:
#
# - Agent: The entity that performs the action.
# - Patient: The entity that undergoes an action or that is being affected by action.
# - Action: The action that is being performed.
#
# Perhaps you meant "Guys, ice the pucks now!" Then, the semantic roles would be as follows:
#
# - Agent: Guys
# - Action: Ice
# - Patient: The pucks
# - Temporal: Now

# %% [markdown]
# Sample 7:confusing sentence with mixed descriptions<br>
# "Though the customer seemed unhappy, she was, in fact satisfied but thinking of something else at the time, which gave a false impression?"

# %%
uinput="Perform Semantic Role Labeling on the following sentence:Though the customer seemed unhappy, she was, in fact satisfied but thinking of something else at the time, which gave a false impression?"
text=dialog(uinput) #preparing the messages for ChatGPT
print("Viewer request",uinput)
print("ChatGPT Sentiment Analysis:",text)
# Out:
# Viewer request Perform Semantic Role Labeling on the following sentence:Though the customer seemed unhappy, she was, in fact satisfied but thinking of something else at the time, which gave a false impression?
# ChatGPT Sentiment Analysis: Semantic Role Labeling (SRL) breaks down a sentence into its semantic arguments and labels them with their roles. Here's the breakdown for the given sentence:
#
# - Though the customer seemed unhappy, she was, in fact satisfied but thinking of something else at the time, which gave a false impression
#
# 1. Argument: the customer
#    Role: Agent (The individual performing or causing the action)
#
# 2. Argument: seemed unhappy
#    Role: Predicate (This gives information about the agent's status)
#
# 3. Argument: she was, in fact satisfied
#    Role: Statement (The fact about the customer's actual feeling)
#
# 4. Argument: thinking of something else at the time
#    Role: Cause/Reason (This explains why she appeared unhappy)
#
# 5. Argument: which gave a false impression
#    Role: Effect/Result (This is the consequence of her thinking about something else.
#
# Notice, these labels are generic and the structure can vary from sentence to sentence while the interpretation can vary too. The idea behind Semantic Role Labeling is to give a better understanding of the underlying situation conveyed in the text.
