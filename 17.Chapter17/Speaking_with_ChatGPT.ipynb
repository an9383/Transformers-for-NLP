# %% [markdown]
# #Speaking with ChatGPT
# Copyright 2023 Denis Rothman, MIT License
#
# This notebook shows how to jump-start ChatGPT with the OpenAI API,speak to it with a microphone, create the ChatGPT request with variables, and listen to the response with Google gTTS.
#
# ChatGPT generates content using gpt-3.5-turbo, OpenAI's.
#
# This notebook creates a speech-to-text and text-to-speech dialog with ChatGPT.
#
# 1. Installing openai, your API key,and [Google gTTS](https://pypi.org/project/gTTS/) for Text-to-Speech<br>
# 2. Entering a request with a microphone<br>
# 3. Generate content with ChatGPT<br>
# 4. Speech-to-text ChatGPT's response<br>
# 5. Transcribing with Whisper
#
# [To understand GPT-3 Transformers in detail, read Transformers for NLP, 2nd Edition](https://www.amazon.com/Transformers-Natural-Language-Processing-architectures/dp/1803247339/ref=tmm_pap_swatch_0?_encoding=UTF8&qid=&sr=)

# %%
# !pip install --upgrade pip
# Out:
# Traceback (most recent call last):
#   File "C:\Users\an9383\AppData\Local\Programs\Python\Python38\lib\runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\an9383\AppData\Local\Programs\Python\Python38\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "d:\WorkSpace\Python\Transformers-for-NLP\venv_38\Scripts\pip.exe\__main__.py", line 4, in <module>
# ModuleNotFoundError: No module named 'pip'

# %% [markdown]
# #1.Installing openai, gTTS, your API Key

# %% [markdown]
# ## installing and importing openai

# %%
#Importing openai
try:
  import openai
except:
  # !pip install openai==0.28
  import openai

# %% [markdown]
# ## installing gTTS
#
# [Google gTTS](https://pypi.org/project/gTTS/)
#
# Text-to-Speech

# %%
#Importing gTTS
try:
  from gtts import gTTS
except:
  # !pip install gTTS
  from gtts import gTTS

# %% [markdown]
# ##API Key

# %%
#2.API Key
#Store you key in a file and read it(you can type it directly in the notebook but it will be visible for somebody next to you)
# from google.colab import drive
# drive.mount('/content/drive')
# f = open("drive/MyDrive/files/api_key.txt", "r")
# API_KEY=f.readline()
# f.close()

#The OpenAI Key
import os
os.environ['OPENAI_API_KEY']
openai.api_key = os.getenv("OPENAI_API_KEY")

# %% [markdown]
# #2.Generating content

# %% [markdown]
# ##speech-to-text

# %% [markdown]
# You can use Windows speech-to-text functionality or any other module you wish.
#
# This notebook uses Windows. Try **Windows key+H** with Windows or read the [documentation for more](https://support.microsoft.com/en-us/windows/dictate-text-using-speech-recognition-854ef1de-7041-9482-d755-8fdf2126ef27).
#
# Note: For this notebook, **press enter when you have finished asking for a request**.
#
# You can adapt the function to your application with a [timed input](https://pypi.org/project/pytimedinput/#:~:text=timedInput(),if%20the%20user%20goes%20idle.) function or other methods.

# %% [markdown]
# ##preparing the prompt

# %% [markdown]
# Note: you can create variables for each part of the OpenAI "messages" object.
#
# For more on implementing each part of the "messages" object, run [Prompt_Engineering_as_an_alternative_to_fine_tuning.ipynb](https://github.com/Denis2054/Transformers-for-NLP-2nd-Edition/blob/main/Chapter17/Prompt_Engineering_as_an_alternative_to_fine_tuning.ipynb).

# %%
#Speech to text. Use OS speech-to-text app. For example,  Windows: press Windows Key+H 
def prepare_message():
 #enter the request with a microphone or type it if you wish
 # example: "Where is Tahiti located?"
 print("Enter a request and press ENTER:")
 uinput = input("")

 #preparing the prompt for OpenAI 
 role="user"
 #prompt="Where is Tahiti located?" #maintenance or if you do not want to use a microphone
 line = {"role": role, "content": uinput}
 
 #creating the message
 assert1={"role": "system", "content": "You are a helpful assistant."}
 assert2={"role": "assistant", "content": "Geography is an important topic if you are going on a once in a lifetime trip."}
 assert3=line
 iprompt = []
 iprompt.append(assert1)
 iprompt.append(assert2)
 iprompt.append(assert3)


 return iprompt

# %%
#run the cell to start/continue a dialog
iprompt=prepare_message() #preparing the messages for ChatGPT
response=openai.ChatCompletion.create(model="gpt-3.5-turbo",messages=iprompt) #ChatGPT dialog
text=response["choices"][0]["message"]["content"] #response in JSON
print("ChatGPT response:",text)
# Out:
# Enter a request and press ENTER:
# ChatGPT response: It seems like there might have been a typo in your message. If you have any questions or need assistance with geography or any other topic, feel free to ask!

# %% [markdown]
# ## sending the request to ChatGPT

# %%
response=openai.ChatCompletion.create(
  model="gpt-3.5-turbo",
  messages=iprompt)

# %%
#extracting the generative AI response
text=response["choices"][0]["message"]["content"]
text
# Out:
# 'If you have any specific questions or need help with anything related to geography or travel, feel free to ask!'

# %% [markdown]
# #4.Speech-to-text response

# %% [markdown]
# ## GTTS and IPython
#
# We'll create the wav file with gTTS and play it with IPython audio

# %%
from gtts import gTTS
from IPython.display import Audio
tts = gTTS(text)
tts.save('1.wav')
sound_file = '1.wav'
Audio(sound_file, autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # 5.Whisper
#
# Whisper can be implemented to transcribe audio files to fit your project: meetings, conferences, other.

# %% [markdown]
# Let's use Whisper to transcribe the file.
#
# Installing an audio processing library: ffmpeg

# %%
# !pip install ffmpeg
# Out:
# Traceback (most recent call last):
#   File "C:\Users\an9383\AppData\Local\Programs\Python\Python38\lib\runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\an9383\AppData\Local\Programs\Python\Python38\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "d:\WorkSpace\Python\Transformers-for-NLP\venv_38\Scripts\pip.exe\__main__.py", line 4, in <module>
# ModuleNotFoundError: No module named 'pip'

# %% [markdown]
# Installing Whisper

# %%
# !pip install git+https://github.com/openai/whisper.git
# Out:
# Traceback (most recent call last):
#   File "C:\Users\an9383\AppData\Local\Programs\Python\Python38\lib\runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\an9383\AppData\Local\Programs\Python\Python38\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "d:\WorkSpace\Python\Transformers-for-NLP\venv_38\Scripts\pip.exe\__main__.py", line 4, in <module>
# ModuleNotFoundError: No module named 'pip'

# %% [markdown]
# Transcribing the wav file

# %%
# !whisper  1.wav
# Out:
# Detecting language using up to the first 30 seconds. Use `--language` to specify the language
# Detected language: English
# [00:00.000 --> 00:07.620]  If you have any specific questions or need help with anything related to geography or travel, feel free to ask.
# d:\workspace\python\transformers-for-nlp\venv_38\lib\site-packages\whisper\model.py:124: UserWarning: 1Torch was not compiled with flash attention. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\native\transformers\cuda\sdp_utils.cpp:455.)
#   a = scaled_dot_product_attention(

# %% [markdown]
# Read json file and display the text object

# %%
import json

with open('1.json') as f:
    data = json.load(f)

text = data['text']
print(text)
# Out:
#  If you have any specific questions or need help with anything related to geography or travel, feel free to ask.
